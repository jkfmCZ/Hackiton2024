# %%
import pandas as pd
import json

# %%
file="hackiton/udesky/data/560.jsonld"
df_ciselnik = pd.read_csv("hackiton/udesky/data/ciselnik.csv")
# df = pd.read_json(file, lines= True,orient= "row")
# print(df)
with open(file, 'r', encoding='utf-8') as file:
    data = json.load(file)

# Normalizace JSON dat do DataFrame
df = pd.json_normalize(data['informace'])

# Zobrazení prvních pár řádků DataFrame
cs = df["název.cs"]
# print(cs)
# df.loc[0].loc["název.cs"]
df_usetecky = df_ciselnik[df_ciselnik["kraj_name"] == "Ústecký kraj"]
# print(df_usetecky)
df_vyhlaseni = df[df['název.cs'].str.contains("Veřejná vyhláška", na=False)]
df_vyhlaseni = df_vyhlaseni[df_vyhlaseni["název.cs"].str.contains('|'.join(df_usetecky["obec_name"]), na=False)]

print(df_vyhlaseni["název.cs"])
# Out:
# 31    Veřejná vyhláška ZDŘ-193/2023-509 Obecné obesl...
# Name: název.cs, dtype: object

# %%
file = "hackiton/udesky/data/soudy_decin.jsonld"
with open(file, 'r', encoding='utf-8') as file:
    data = json.load(file)

# Normalizace JSON dat do DataFrame
df = pd.json_normalize(data['informace'])
print(df)
df['vyvěšení.datum_a_čas'] = pd.to_datetime(df['vyvěšení.datum_a_čas'])

# Extrahování roku a uložení do nového sloupce
df['rok_vyvěšení'] = df['vyvěšení.datum_a_čas'].dt.year
df["count"] = 1
df_count_per_year = df.groupby('rok_vyvěšení').size().reset_index(name='count')

# Resetování indexu pro pěknější výstup
df_count_per_year.reset_index(drop=True, inplace=True)
print(df_count_per_year)
data = {
    'název_obce': [],
    '2023': [],
    '2024': []}
df = pd.DataFrame()
# Out:
#         spisová_značka               revize  \
# 0      35 D 240 / 2020   05.12.2023 7:29:07
# 1       31 T 71 / 2023   12.02.2024 7:30:41
# 2     35 D 1054 / 2019  07.12.2023 10:28:14
# 3      EPR 4392 / 2024  17.05.2024 10:07:03
# 4     EPR 28176 / 2024   23.05.2024 9:08:08
# ..                 ...                  ...
# 498     26 C 79 / 2023   02.05.2024 9:03:35
# 499    21 C 141 / 2023   02.05.2024 9:03:35
# 500    19 C 121 / 2024  21.05.2024 12:30:55
# 501    21 C 208 / 2023   02.05.2024 9:13:38
# 502     11 C 96 / 2024  24.05.2024 13:03:27
#
#                                               dokument  \
# 0    [{'typ': ['Digitální objekt'], 'url': 'https:/...
# 1    [{'typ': ['Digitální objekt'], 'url': 'https:/...
# 2    [{'typ': ['Digitální objekt'], 'url': 'https:/...
# 3    [{'typ': ['Digitální objekt'], 'url': 'https:/...
# 4    [{'typ': ['Digitální objekt'], 'url': 'https:/...
# ..                                                 ...
# 498  [{'typ': ['Digitální objekt'], 'url': 'https:/...
# 499  [{'typ': ['Digitální objekt'], 'url': 'https:/...
# 500  [{'typ': ['Digitální objekt'], 'url': 'https:/...
# 501  [{'typ': ['Digitální objekt'], 'url': 'https:/...
# 502  [{'typ': ['Digitální objekt'], 'url': 'https:/...
#
#                                                 agenda  \
# 0      [{'typ': 'Agenda', 'název': {'cs': 'Dědické'}}]
# 1      [{'typ': 'Agenda', 'název': {'cs': 'Trestní'}}]
# 2      [{'typ': 'Agenda', 'název': {'cs': 'Dědické'}}]
# 3    [{'typ': 'Agenda', 'název': {'cs': 'Platební r...
# 4    [{'typ': 'Agenda', 'název': {'cs': 'Platební r...
# ..                                                 ...
# 498  [{'typ': 'Agenda', 'název': {'cs': 'Občanskopr...
# 499  [{'typ': 'Agenda', 'název': {'cs': 'Občanskopr...
# 500  [{'typ': 'Agenda', 'název': {'cs': 'Občanskopr...
# 501  [{'typ': 'Agenda', 'název': {'cs': 'Občanskopr...
# 502  [{'typ': 'Agenda', 'název': {'cs': 'Občanskopr...
#
#                                                typ  \
# 0    [Digitální objekt, Informace na úřední desce]
# 1    [Digitální objekt, Informace na úřední desce]
# 2    [Digitální objekt, Informace na úřední desce]
# 3    [Digitální objekt, Informace na úřední desce]
# 4    [Digitální objekt, Informace na úřední desce]
# ..                                             ...
# 498  [Digitální objekt, Informace na úřední desce]
# 499  [Digitální objekt, Informace na úřední desce]
# 500  [Digitální objekt, Informace na úřední desce]
# 501  [Digitální objekt, Informace na úřední desce]
# 502  [Digitální objekt, Informace na úřední desce]
#
#                                                    url  \
# 0    https://infodeska.justice.cz/vyveseni.aspx?vyv...
# 1    https://infodeska.justice.cz/vyveseni.aspx?vyv...
# 2    https://infodeska.justice.cz/vyveseni.aspx?vyv...
# 3    https://infodeska.justice.cz/vyveseni.aspx?vyv...
# 4    https://infodeska.justice.cz/vyveseni.aspx?vyv...
# ..                                                 ...
# 498  https://infodeska.justice.cz/vyveseni.aspx?vyv...
# 499  https://infodeska.justice.cz/vyveseni.aspx?vyv...
# 500  https://infodeska.justice.cz/vyveseni.aspx?vyv...
# 501  https://infodeska.justice.cz/vyveseni.aspx?vyv...
# 502  https://infodeska.justice.cz/vyveseni.aspx?vyv...
#
#                                                    iri    vyvěšení.typ  \
# 0    https://data.justice.cz/zdroj/úřední_deska/000...  Časový okamžik
# 1    https://data.justice.cz/zdroj/úřední_deska/000...  Časový okamžik
# 2    https://data.justice.cz/zdroj/úřední_deska/000...  Časový okamžik
# 3    https://data.justice.cz/zdroj/úřední_deska/000...  Časový okamžik
# 4    https://data.justice.cz/zdroj/úřední_deska/000...  Časový okamžik
# ..                                                 ...             ...
# 498  https://data.justice.cz/zdroj/úřední_deska/000...  Časový okamžik
# 499  https://data.justice.cz/zdroj/úřední_deska/000...  Časový okamžik
# 500  https://data.justice.cz/zdroj/úřední_deska/000...  Časový okamžik
# 501  https://data.justice.cz/zdroj/úřední_deska/000...  Časový okamžik
# 502  https://data.justice.cz/zdroj/úřední_deska/000...  Časový okamžik
#
#     vyvěšení.datum_a_čas                                           název.cs  \
# 0    2023-12-05T07:29:07  Vyrozumění neznámého dědice - zůst. Josef Vojt...
# 1    2024-02-12T07:30:41                      Veřejné vyhlášení popisu věci
# 2    2023-12-07T10:28:14  Vyrozumění dědice neznámého pobytu - Lukáš Ran...
# 3    2024-05-17T10:07:03  Sdělení pro vyvěšení na úřední desce soudu pod...
# 4    2024-05-23T09:08:08  Sdělení pro vyvěšení na úřední desce soudu pod...
# ..                   ...                                                ...
# 498  2024-05-02T09:03:35  Sdělení pro vyvěšení na úřední desce soudu pod...
# 499  2024-05-02T09:03:35  Sdělení pro vyvěšení na úřední desce soudu pod...
# 500  2024-05-21T12:30:55  Sdělení pro vyvěšení na úřední desce soudu pod...
# 501  2024-05-02T09:13:38  Sdělení pro vyvěšení na úřední desce soudu pod...
# 502  2024-05-24T13:03:27  Sdělení pro vyvěšení na úřední desce soudu pod...
#
#     relevantní_do.typ relevantní_do.datum relevantní_do.datum_a_čas
# 0      Časový okamžik          2024-06-06                       NaN
# 1      Časový okamžik                 NaN       2024-08-12T07:28:25
# 2      Časový okamžik          2024-06-08                       NaN
# 3      Časový okamžik                 NaN       2024-06-17T10:06:27
# 4      Časový okamžik                 NaN       2024-06-24T09:08:06
# ..                ...                 ...                       ...
# 498    Časový okamžik          2024-06-04                       NaN
# 499    Časový okamžik          2024-06-04                       NaN
# 500    Časový okamžik          2024-06-21                       NaN
# 501    Časový okamžik          2024-06-04                       NaN
# 502    Časový okamžik          2024-06-25                       NaN
#
# [503 rows x 13 columns]
#    rok_vyvěšení  count
# 0          2023      2
# 1          2024    501
